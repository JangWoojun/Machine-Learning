# %%
import numpy as np
import pandas as pd

# %%
perch = pd.read_csv("/content/drive/MyDrive/30619 장우준 인공지능/dataset/perch단순회귀.csv")
perch.sample(5)
# Out:
#    Species  Weight  Length  Diagonal   Height   Width
# 9    Perch    85.0    20.0      21.0   5.0820  2.7720
# 52   Perch  1000.0    43.0      45.2  11.9328  7.2772
# 44   Perch   900.0    39.0      41.4  11.1366  7.4934
# 17   Perch   135.0    22.0      23.5   5.8750  3.5250
# 34   Perch   250.0    28.0      29.4   7.8204  4.2042

# %%
perch.describe()
# Out:
#             Weight     Length   Diagonal     Height      Width
# count    56.000000  56.000000  56.000000  56.000000  56.000000
# mean    382.239286  27.892857  29.571429   7.861870   4.745723
# std     347.617717   9.021668   9.529509   2.878177   1.774626
# min       5.900000   8.400000   8.800000   2.112000   1.408000
# 25%     120.000000  21.825000  23.325000   5.692500   3.525000
# 50%     207.500000  25.300000  26.750000   6.921800   4.154900
# 75%     692.500000  36.625000  39.075000  10.846500   6.448125
# max    1100.000000  44.000000  46.600000  12.800200   8.142000

# %%
perch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Species   56 non-null     object
#  1   Weight    56 non-null     float64
#  2   Length    56 non-null     float64
#  3   Diagonal  56 non-null     float64
#  4   Height    56 non-null     float64
#  5   Width     56 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.8+ KB

# %%
X = perch.drop(columns=["Weight", "Species"])
y = perch["Weight"]
display(X, y)
# Out:
#     Length  Diagonal   Height   Width
# 0      8.4       8.8   2.1120  1.4080
# 1     13.7      14.7   3.5280  1.9992
# 2     15.0      16.0   3.8240  2.4320
# 3     16.2      17.2   4.5924  2.6316
# 4     17.4      18.5   4.5880  2.9415
# 5     18.0      19.2   5.2224  3.3216
# 6     18.7      19.4   5.1992  3.1234
# 7     19.0      20.2   5.6358  3.0502
# 8     19.6      20.8   5.1376  3.0368
# 9     20.0      21.0   5.0820  2.7720
# 10    21.0      22.5   5.6925  3.5550
# 11    21.0      22.5   5.9175  3.3075
# 12    21.0      22.5   5.6925  3.6675
# 13    21.3      22.8   6.3840  3.5340
# 14    22.0      23.5   6.1100  3.4075
# 15    22.0      23.5   5.6400  3.5250
# 16    22.0      23.5   6.1100  3.5250
# 17    22.0      23.5   5.8750  3.5250
# 18    22.0      23.5   5.5225  3.9950
# 19    22.5      24.0   5.8560  3.6240
# 20    22.5      24.0   6.7920  3.6240
# 21    22.7      24.2   5.9532  3.6300
# 22    23.0      24.5   5.2185  3.6260
# 23    23.5      25.0   6.2750  3.7250
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_scaled = ss.fit_transform(X)
display(X_scaled)
# Out:
# array([[-2.18022506, -2.19942184, -2.01582665, -1.89782472],
#        [-1.58743393, -1.57468923, -1.51939617, -1.56166923],
#        [-1.44203233, -1.43703628, -1.41562257, -1.31557976],
#        [-1.30781547, -1.30997202, -1.14623191, -1.20208748],
#        [-1.17359861, -1.17231907, -1.14777449, -1.02587878],
#        [-1.10649018, -1.09819825, -0.92536241, -0.80975445],
#        [-1.02819702, -1.07702087, -0.93349602, -0.92245069],
#        [-0.9946428 , -0.99231137, -0.78042996, -0.96407211],
#        [-0.92753437, -0.92877924, -0.95509215, -0.97169133],
#        [-0.88279542, -0.90760186, -0.97458476, -1.12225624],
#        [-0.77094803, -0.74877153, -0.7605517 , -0.67704354],
#        [-0.77094803, -0.74877153, -0.68166974, -0.81777169],
#        [-0.77094803, -0.74877153, -0.7605517 , -0.6130762 ],
#        [-0.73739382, -0.71700547, -0.51812114, -0.68898411],
#        [-0.65910065, -0.64288465, -0.61418184, -0.76091183],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (44, 4) (12, 4) (44,) (12,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
print(f"기울기: {lr.coef_}")
print(f"절편: {lr.intercept_}")
# Out:
# 기울기: [ 557.28590892 -534.42360155  102.53224695  204.84710443]
# 절편: 383.5117420639862

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
lr_pred = lr.predict(X_test)

print(f"mae = {mean_absolute_error(y_test, lr_pred)}")
print(f"mse = {mean_squared_error(y_test, lr_pred)}")
print(f"rms = {np.sqrt(mean_squared_error(y_test, lr_pred))}")
print(f"mape = {mean_absolute_percentage_error(y_test, lr_pred)}")
print(f"r2 score= {r2_score(y_test, lr_pred)}")
print(f"lr test score = {lr.score(X_test, y_test)}")
# Out:
# mae = 73.71439530206955
# mse = 10351.575138114871
# rms = 101.74269083386221
# mape = 0.27407643033240986
# r2 score= 0.8979422481424585
# lr test score = 0.8979422481424585

# %%
import matplotlib.pyplot as plt

c = range(0, 12)
plt.plot(c, y_test, c="r")
plt.plot(c, lr_pred, c="b")
plt.xlabel("index")
plt.ylabel("weight")
plt.show()

# %%
residual = y_test - lr_pred
plt.plot(c, residual, c="g")
plt.xlabel("index")
plt.ylabel("residual")
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
print(f"DTR train set: {dt.score(X_train, y_train)}")
print(f"DTR test set: {dt.score(X_test, y_test)}")
print(f"DTR depth: {dt.get_depth()}")
# Out:
# DTR train set: 1.0
# DTR test set: 0.7978337765815188
# DTR depth: 8

# %%
dt_pred = dt.predict(X_test)

print(f"mae = {mean_absolute_error(y_test, dt_pred)}")
print(f"mse = {mean_squared_error(y_test, dt_pred)}")
print(f"rms = {np.sqrt(mean_squared_error(y_test, dt_pred))}")
print(f"mape = {mean_absolute_percentage_error(y_test, dt_pred)}")
print(f"r2 score= {r2_score(y_test, dt_pred)}")
print(f"dt test score = {dt.score(X_test, y_test)}")
# Out:
# mae = 75.625
# mse = 20505.4375
# rms = 143.1971979474459
# mape = 0.17923092954812592
# r2 score= 0.7978337765815188
# dt test score = 0.7978337765815188

# %%
plt.figure(figsize=(40, 20))
plot_tree(dt, feature_names=X.columns)
plt.show()

# %%
dt2 = DecisionTreeRegressor(max_depth=3)
dt2.fit(X_train, y_train)
print(f"DTR train set: {dt.score(X_train, y_train)}")
print(f"DTR test set: {dt.score(X_test, y_test)}")
# Out:
# DTR train set: 1.0
# DTR test set: 0.7999781421232693

# %%
plt.figure(figsize=(40, 20))
plot_tree(dt2, feature_names=X.columns)
plt.show()
